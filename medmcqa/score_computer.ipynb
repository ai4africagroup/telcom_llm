# %%
import pandas as pd
pred = pd.read_csv("medmcq_qwen3B_ans_k_1.csv")["Answer_ID"]
pred_b = pd.read_csv("medmcq_qwen3B_ans_k_.csv")["Answer_ID"]

ans = pd.read_csv("dev_answers.csv")["Answer_ID"]
sum(ans == pred_b)/len(pred)

# %%
import pandas as pd
pred = pd.read_csv("medmcq_phi_ans_k_1.csv")["Answer_ID"]
pred_b = pd.read_csv("medmcq_phi_ans_k_20.csv")["Answer_ID"]

ans = pd.read_csv("dev_answers.csv")["Answer_ID"]
sum(ans == pred_b)/len(pred)
# Out:
# 0.361224001912503
